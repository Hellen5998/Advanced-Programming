# %%
from selenium import webdriver

# %%
browser=webdriver.Chrome()

# %%
browser.get('http://www.guoxuedashi.com/zidian')

# %%
input=browser.find_element_by_id('sokeyzi')

# %%
input.send_keys('一')

# %%
from selenium.webdriver.common.keys import Keys
input.send_keys(Keys.ENTER)

# %%
#from selenium.webdriver.common.by import By
elem=browser.find_element_by_css_selector("#shupage > tbody:nth-child(1) > tr:nth-child(2) > td:nth-child(2)")
#shupage > tbody:nth-child(1) > tr:nth-child(2) > td:nth-child(2)

# %%
#len(elem)
# Out:
# 23

# %%
#for i in range(0,len(elem)):
 #   browser.find_elements_by_css_selector("#shupage > tbody:nth-child(1) >trnth-child("+i+")").find_element_by_tag_name("a")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-252-34d230e1c7d8> in <module>()
#       1 for i in range(0,len(elem)):
#       2     str(i)
# ----> 3     browser.find_elements_by_css_selector("#shupage > tbody:nth-child(1) >trnth-child("+i+")").find_element_by_tag_name("a")
#
# TypeError: must be str, not int

# %%
elem.click()

# %%
import time
time.sleep(10)
browser.switch_to.window(browser.window_handles[-1])
sreach_window3=browser.current_window_handle
browser.current_url
#browser.find_element_by_css_selector("body > div:nth-child(4) > center:nth-child(2) > img").get_attribute('src')
# Out:
# 'http://www.guoxuedashi.com/kangxi/pic.php?f=dzd&p=1'

# %%
browser.find_element_by_css_selector("body > div:nth-child(4) > center:nth-child(2) > img").get_attribute('src')
# Out:
# 'http://pic.guoxuedashi.com/hydzd/1.gif'

# %%
dir(elem.find_element_by_tag_name("a"))
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_execute',
#  '_id',
#  '_parent',
#  '_upload',
#  '_w3c',
#  'clear',
#  'click',
#  'find_element',
#  'find_element_by_class_name',
#  'find_element_by_css_selector',
#  'find_element_by_id',
#  'find_element_by_link_text',
#  'find_element_by_name',
#  'find_element_by_partial_link_text',
#  'find_element_by_tag_name',
#  'find_element_by_xpath',
#  'find_elements',
#  'find_elements_by_class_name',
#  'find_elements_by_css_selector',
#  'find_elements_by_id',
#  'find_elements_by_link_text',
#  'find_elements_by_name',
#  'find_elements_by_partial_link_text',
# ...

# %%
for e in elem:
    print(e.text)
# Out:
# 二十四史
# 四库全书
# 古今图书集成
# 历史人物
# 说文解字
# 成语词典
# 甲骨文合集
# 殷周金文集成
# 象形字典
# 十三经索引
# 字体转换器
# 篆书识别
# 近义反义词
# 对联大全
# 电子书下载
# 哈佛古籍
#
#
#
# 添加收藏
# 搜索引擎
# 赞助本站
#
# 首页
# 国学书库
# 影印古籍
# 诗词宝典
# 精选
# 汉语字典
# 汉语词典
# 书法字典
# 部件查字
# 甲骨文
# 解密
# 历史人物
# 历史典故
# 姓氏
# 民族
# 世界名著
# 软件下载
# 历史
# 四库全书
# 全文检索
# 古籍书目
# 正史
# 成语词典
# 康熙字典
# 说文解字
# 字形演变
# 金　文
# 年号
# 历史地名
# 历史事件
# 官职
# 知识
# 中医中药
# 留言反馈
#
#
#
#
#
#
# 部件查字
# 拼音索引
# 部首索引
#
# 首页
# 汉语字典
# 弌
# 壹
# 𠤪
# 壹
# 点此查看：【一】更详细解释
# 【一】在《汉语大词典》中的解释
# 第1页
# 文字版
# 第1页
# 第1页
# 文字版
# 第1521页
# 第1522页
# 第1页
# 文字版
# 第1页
# 第156页
# 文字版
# 第75页
# 文字版
# 第1页
# 𠤪
# 弌
#
#
#
# 壹
# 详情
# 第1页
# 文字版
# 第22页
# 文字版
# 第13页
# 第1页
# 文字版
# 第1页
# 第1页
# 第1页
# 第1页
# 第1页
# 第8623页 入聲,四質(韻目第8594頁)
# 第8720页 入聲,四質,補遺(韻目第8704頁)
# 文字版
# 第1页
# 第977页
# 补遗：16135
# 补编：14867
# 汉字宝典
# 腾讯微博
# 微信
# 新浪微博
# 人人网
# QQ空间
# 百度贴吧
# 更多
# 历史地图
# 英语宝典
# 十三经检索
# 古今图书集成
# 象形文字典
# 对联大全
# 字形演变
# 哈佛燕京中文善本特藏
# 丛书&方志检索器
# 家谱族谱查询
# 一切经音义
# 书法字帖欣赏
#
# app软件下载专区
# 《国学大师》下载
# 《汉字宝典》下载
# 《诗词曲宝典》下载
# 《四库全书》下载
# 如何在国学大师网下载古籍？
# 如何使用部件查字法快速查字？
# ...

# %%
elem=browser.find_element_by_css_selector("#shupage > tbody > tr:nth-child(2) > td:nth-child(2) > a")

# %%
elem
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="dea6cf2b8f3d3cab9dc1fea7b36aae91", element="0.6237064936187737-1")>

# %%
elem.click()
